# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('/content/tested.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# #Catorigical data

# %% [markdown]
# ##Countplot

# %%
sns.countplot(df,x='Survived')#yo pani hunxa tara plot matraa
df['Survived'].value_counts().plot(kind='bar') ##yo pani hunxa  with values of ploted
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(df,x='Pclass')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# #Pic chart

# %%
df['Embarked'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #Numerical Graph

# %% [markdown]
# ##Histrograph

# %%
##Giving a range
import matplotlib.pyplot as plt

# %%
plt.hist(df['Age'],bins=50) ##bins hepls to make a catograties or expand the no of points
# Out:
# (array([ 8.,  3.,  0.,  4.,  1.,  4.,  2.,  3.,  3.,  4.,  2., 20.,  7.,
#         25., 17., 28., 11., 25.,  8., 25., 12.,  8.,  7., 10.,  6.,  7.,
#         11.,  5.,  5.,  9.,  8.,  5.,  8.,  1.,  3.,  2.,  6.,  3.,  2.,
#          4.,  3.,  2.,  3.,  0.,  1.,  0.,  0.,  0.,  0.,  1.]),
#  array([ 0.17  ,  1.6866,  3.2032,  4.7198,  6.2364,  7.753 ,  9.2696,
#         10.7862, 12.3028, 13.8194, 15.336 , 16.8526, 18.3692, 19.8858,
#         21.4024, 22.919 , 24.4356, 25.9522, 27.4688, 28.9854, 30.502 ,
#         32.0186, 33.5352, 35.0518, 36.5684, 38.085 , 39.6016, 41.1182,
#         42.6348, 44.1514, 45.668 , 47.1846, 48.7012, 50.2178, 51.7344,
#         53.251 , 54.7676, 56.2842, 57.8008, 59.3174, 60.834 , 62.3506,
#         63.8672, 65.3838, 66.9004, 68.417 , 69.9336, 71.4502, 72.9668,
#         74.4834, 76.    ]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# #b. Distplot

# %%
sns.distplot(df['Age'])
# Out:
# /tmp/ipykernel_635/3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# #Box plot

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df['Age'].min()
# Out:
# 0.17

# %%
df['Age'].max()
# Out:
# 76.0

# %%
df['Age'].mean()
# Out:
# np.float64(30.272590361445783)

# %%
df['Age'].skew()
# Out:
# np.float64(0.4573612871503845)
