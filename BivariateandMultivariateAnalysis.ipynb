# %%
import pandas as pd
import seaborn as sns

# %%
cr = pd.read_csv("/content/tips.csv")

# %% [markdown]
# #Scatter (N -N)

# %%
cr.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=cr, x='total_bill', y='tip') ##Relation between both column
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=cr, x='total_bill', y='tip',hue=cr['sex'])  ##multi
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=cr, x='total_bill', y='tip',hue=cr['sex'],style=cr['smoker'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=cr, x='total_bill', y='tip',hue=cr['sex'],style=cr['smoker'],size=cr['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=cr, x='total_bill', y='tip',hue=cr['sex'],style=cr['smoker'],size=cr['day'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# #Bar Plot (N - C)

# %%
df = pd.read_csv("/content/tested.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
sns.barplot(data=df,x='Pclass',y='Age')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.barplot(data=df,x='Fare',y='Age')
# Out:
# <Axes: xlabel='Fare', ylabel='Age'>

# %%
sns.barplot(data=df,x='Pclass',y='Fare')
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.barplot(data=df,x='Pclass',y='Age',hue=df['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# #Box Plot (N - C)

# %%
sns.boxplot(data=df,x='Sex',y='Age')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(data=df,x='Sex',y='Age',hue=df['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# #DiscPlot (N-C)

# %%
sns.distplot(df[df['Survived']==0]['Age'])
sns.distplot(df[df['Survived']==1]['Age'])
# Out:
# /tmp/ipykernel_1487/1811681565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Survived']==0]['Age'])
# /tmp/ipykernel_1487/1811681565.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Survived']==1]['Age'])
# ...

# %%
sns.distplot(df[df['Survived']==0]['Age'],hist=False)
sns.distplot(df[df['Survived']==1]['Age'],hist=False)
# Out:
# /tmp/ipykernel_1487/455601345.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Survived']==0]['Age'],hist=False)
# /tmp/ipykernel_1487/455601345.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# #HeatMap ( C-C)

# %%
pd.crosstab(df['Pclass'],df['Survived'])
# Out:
# Survived    0   1
# Pclass
# 1          57  50
# 2          63  30
# 3         146  72

# %%
sns.heatmap(pd.crosstab(df['Pclass'],df['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
df.groupby('Pclass')['Survived'].mean()*100
# Out:
# Pclass
# 1    46.728972
# 2    32.258065
# 3    33.027523
# Name: Survived, dtype: float64

# %%
(df.groupby('Pclass')['Survived'].mean()*100).plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
 (df.groupby('Embarked')['Survived'].mean()*100).plot(kind='bar')
# Out:
# <Axes: xlabel='Embarked'>

# %% [markdown]
# #ClusterMap (C-C)

# %%
pd.crosstab(df['SibSp'],df['Survived'])
# Out:
# Survived    0   1
# SibSp
# 0         195  88
# 1          56  54
# 2           8   6
# 3           3   1
# 4           3   1
# 5           0   1
# 8           1   1

# %%
sns.clustermap(pd.crosstab(df['SibSp'],df['Survived']))

# %% [markdown]
# #Pair Plot(ALL IN ONE FOR PLOTS AND GRAPHS)

# %%
sns.pairplot(cr)

# %%
sns.pairplot(cr,hue='sex')

# %% [markdown]
# #LinePlot(N-N)

# %%
ron=pd.read_csv('/content/CR7data.csv')

# %%
ron
# Out:
#     Season               Competition      Matchday      Date Venue  \
# 0    02/03             Liga Portugal             6  10-07-02     H
# 1    02/03             Liga Portugal             6  10-07-02     H
# 2    02/03             Liga Portugal             8  10/26/02     A
# 3    02/03  Taca de Portugal Placard  Fourth Round  11/24/02     H
# 4    02/03  Taca de Portugal Placard   Fifth Round  12/18/02     H
# ..     ...                       ...           ...       ...   ...
# 705  22/23          Saudi Pro League            16    2/9/23     A
# 706  22/23          Saudi Pro League            18   2/25/23     A
# 707  22/23          Saudi Pro League            18   2/25/23     A
# 708  22/23          Saudi Pro League            18   2/25/23     A
# 709  22/23          Saudi Pro League            21   3/18/23     H
#
#             Club                 Opponent Result Playing_Position Minute  \
# 0    Sporting CP            Moreirense FC   3:00               LW     34
# ...

# %%
cr.groupby('tip').sum()
# Out:
#        total_bill                     sex       smoker           day  \
# tip
# 1.00        28.67  FemaleFemaleFemaleMale  YesYesNoYes  SatFriSatSat
# 1.01        16.99                  Female           No           Sun
# 1.10        12.90                  Female          Yes           Sat
# 1.17        32.83                    Male          Yes           Sat
# 1.25        29.09          MaleFemaleMale       NoNoNo    SatThurSat
# ...           ...                     ...          ...           ...
# 6.70        34.30                    Male           No          Thur
# 6.73        48.27                    Male           No           Sat
# 7.58        39.42                    Male           No           Sat
# 9.00        48.33                    Male           No           Sat
# 10.00       50.81                    Male          Yes           Sat
#
#                            time  size
# tip
# 1.00   DinnerDinnerDinnerDinner     6
# 1.01                     Dinner     2
# ...

# %%
new=cr.groupby('tip').sum()
